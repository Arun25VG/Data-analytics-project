# %% [markdown]
# # ITP Mini Project

# %% [markdown]
# # Problem Statement
# For a seamless eCommerce shopping experience, it is essential to deliver the product promptly to the customer. And that’s where a professional courier service plays a vital role.          "Fastrack" courier company stores the relevant data of its clients and parcels in the form of a dictionary. Create a dictionary for storing shipment information in key-value pairs. Shipment id is used as a key and a list of other attributes like sender, receiver, start date, Delivery Date,sender_location, Receiver_location, Delivery status, Shipping cost is associated with the shipment id. Use the data shown in the table below.

# %% [markdown]
# ![table.png](attachment:table.png)

# %% [markdown]
# # Use below table to refer to clients data. Please note that a client can be a sender or receiver.

# %% [markdown]
# ![table_1.png](attachment:table_1.png)

# %% [markdown]
# # Q1. Create a Dictionary of lists to store the information of shipments given in the table.

# %%
ship={101:[1,3,'14-03-2020','25-03-2020','Area1','Area6','Delivered',198],102:[4,1,'18-6-2020','09-07-2020','Area2','Area4','Delivered',275],
     103:[2,3,'01-12-2020','Null','Area5','Area1','In-Transit',200],104:[1,5,'23-06-2020','25-06-2020','Area1','Area4','Delivered',314],105:
     [3,4,'29-08-2020','10-09-2020','Area5','Area3','Delivered',275],106:[5,2,'28-06-2020','Null','Area3','Area1','In-Transit',270]}
ship
# Out:
# {101: [1, 3, '14-03-2020', '25-03-2020', 'Area1', 'Area6', 'Delivered', 198],
#  102: [4, 1, '18-6-2020', '09-07-2020', 'Area2', 'Area4', 'Delivered', 275],
#  103: [2, 3, '01-12-2020', 'Null', 'Area5', 'Area1', 'In-Transit', 200],
#  104: [1, 5, '23-06-2020', '25-06-2020', 'Area1', 'Area4', 'Delivered', 314],
#  105: [3, 4, '29-08-2020', '10-09-2020', 'Area5', 'Area3', 'Delivered', 275],
#  106: [5, 2, '28-06-2020', 'Null', 'Area3', 'Area1', 'In-Transit', 270]}

# %% [markdown]
# # Q2. Create a Dictionary to store the information of clients given in the table.

# %%
dict_client={1:'Philip',2:'Omega',3:'Ramya',4:'Romesh',5:'John'}
dict_client
# Out:
# {1: 'Philip', 2: 'Omega', 3: 'Ramya', 4: 'Romesh', 5: 'John'}

# %% [markdown]
# # Q3. Write a code to replace clients' IDs with their respective names in the shipment dictionary using a loop and dictionary comprehension.

# %%
for  i in ship: 
    for j in dict_client:
        if ship[i][0]==j:
            ship[i][0]=dict_client[j]
        elif ship[i][1]==j:
            ship[i][1]=dict_client[j]
print(ship)
# Out:
# {101: ['Philip', 'Ramya', '14-03-2020', '25-03-2020', 'Area1', 'Area6', 'Delivered', 198], 102: ['Romesh', 'Philip', '18-6-2020', '09-07-2020', 'Area2', 'Area4', 'Delivered', 275], 103: ['Omega', 'Ramya', '01-12-2020', 'Null', 'Area5', 'Area1', 'In-Transit', 200], 104: ['Philip', 'John', '23-06-2020', '25-06-2020', 'Area1', 'Area4', 'Delivered', 314], 105: ['Ramya', 'Romesh', '29-08-2020', '10-09-2020', 'Area5', 'Area3', 'Delivered', 275], 106: ['John', 'Omega', '28-06-2020', 'Null', 'Area3', 'Area1', 'In-Transit', 270]}

# %% [markdown]
# # Q4. Print all shipment details that are sent by Phillip

# %%
for i in ship:
    if ship[i][0]=='Philip':
        print(ship[i])
# Out:
# ['Philip', 'Ramya', '14-03-2020', '25-03-2020', 'Area1', 'Area6', 'Delivered', 198]
# ['Philip', 'John', '23-06-2020', '25-06-2020', 'Area1', 'Area4', 'Delivered', 314]

# %% [markdown]
# # Q5. Print all shipment details that are received by Ramya

# %%
for i in ship:
    if ship[i][1]=='Ramya':
        print(ship[i])
# Out:
# ['Philip', 'Ramya', '14-03-2020', '25-03-2020', 'Area1', 'Area6', 'Delivered', 198]
# ['Omega', 'Ramya', '01-12-2020', 'Null', 'Area5', 'Area1', 'In-Transit', 200]

# %% [markdown]
# # Q6. Print all shipments which are in 'In-Transit' status

# %%
for i in ship:
    if ship[i][6]=='In-Transit':
        print(ship[i])
# Out:
# ['Omega', 'Ramya', '01-12-2020', 'Null', 'Area5', 'Area1', 'In-Transit', 200]
# ['John', 'Omega', '28-06-2020', 'Null', 'Area3', 'Area1', 'In-Transit', 270]

# %% [markdown]
# # Q7. Print all shipments which are delivered within 7 days of courier Start date

# %%
ship={101: ['Philip', 'Ramya', '14-03-2020', '25-03-2020', 'Area1', 'Area6', 'Delivered', 198], 102: ['Romesh', 'Philip', '18-6-2020', '09-07-2020', 'Area1', 'Area4', 'Delivered', 275], 103: ['Omega', 'Ramya', '01-12-2020', 'Null', 'Area5', 'Area1', 'In-Transit', 200], 104: ['Philip', 'John', '23-06-2020', '25-06-2020', 'Area1', 'Area4', 'Delivered', 314], 105: ['Ramya', 'Romesh', '29-08-2020', '10-09-2020', 'Area5', 'Area3', 'Delivered', 275], 106: ['John', 'Omega', '28-06-2020', 'Null', 'Area3', 'Area1', 'In-Transit', 270]}
ship_7d=[]
from datetime import*
for i in ship.keys():
     if ship[i][3]!='Null' and (datetime.strptime(ship[i][3],"%d-%m-%Y")-datetime.strptime(ship[i][2],"%d-%m-%Y")).days<=7:
            ship_7d.append(ship[i][:-1])
print(ship_7d)
# Out:
# [['Philip', 'John', '23-06-2020', '25-06-2020', 'Area1', 'Area4', 'Delivered']]

# %% [markdown]
# # Q8. Print all shipments which are delivered after 15 days of courier start date or have not yet been delivered.

# %%
ship=delivery={101:[1, 3, '14-03-2020','25-03-2020','Area1','Area6','Delivered',198],102:[4,1,'18-06-2020','09-07-2020','Area2','Area4','Delivered',275],103:[2,3,'01-12-2020','Null','Area5','Area1','In-Transit',200],104:[1,5,'23-06-2020','25-06-2020','Area1','Area4','Delivered',314],105:[3,4,'29-08-2020','10-09-2020','Area5','Area3','Delivered',275],106:[5,2,'28-06-2020','Null','Area3','Area1','In-Transit',270]}
delay_delivery=[]
from datetime import*
for i in ship:
    if ship[i][3]=='Null' or (datetime.strptime(ship[i][3],"%d-%m-%Y")-datetime.strptime(ship[i][2],"%d-%m-%Y")).days>15:
        delay_delivery.append(ship[i])
print(delay_delivery)
# Out:
# [[4, 1, '18-06-2020', '09-07-2020', 'Area2', 'Area4', 'Delivered', 275], [2, 3, '01-12-2020', 'Null', 'Area5', 'Area1', 'In-Transit', 200], [5, 2, '28-06-2020', 'Null', 'Area3', 'Area1', 'In-Transit', 270]]
